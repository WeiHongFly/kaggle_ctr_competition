# %%
from __future__ import division,absolute_import,print_function
import pandas as pd
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
pd.set_option('max_columns',None) 
pd.set_option('max_row',None) 
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
data_base_dir="E:/python_project/kaggle_ctr_prediction/data_source/data"
train_dir=os.path.join(data_base_dir,"train.csv")
test_dir=os.path.join(data_base_dir,"test.csv")
train_df_sample=pd.read_csv(train_dir,nrows=100000)
test_df_sample=pd.read_csv(test_dir,nrows=100000)

# %%
train_df_sample.head(10)
# Out:
#                           id  click      hour    C1  banner_pos   site_id  \
# 0  1000009418151094272.00000      0  14102100  1005           0  1fbe01fe
# 1 10000169349117863936.00000      0  14102100  1005           0  1fbe01fe
# 2 10000371904215119872.00000      0  14102100  1005           0  1fbe01fe
# 3 10000640724480839680.00000      0  14102100  1005           0  1fbe01fe
# 4 10000679056417042432.00000      0  14102100  1005           1  fe8cc448
# 5 10000720757801103360.00000      0  14102100  1005           0  d6137915
# 6 10000724729988544512.00000      0  14102100  1005           0  8fda644b
# 7 10000918755742328832.00000      0  14102100  1005           1  e151e245
# 8 10000949271186030592.00000      1  14102100  1005           0  1fbe01fe
# 9 10001264480619466752.00000      0  14102100  1002           0  84c7ba46
#
#   site_domain site_category    app_id app_domain app_category device_id  \
# 0    f3845767      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# ...

# %%
test_df_sample.head(10)
# Out:
#                      id      hour    C1  banner_pos   site_id site_domain  \
# 0  10000174058809263569  14103100  1005           0  235ba823    f6ebf28e
# 1  10000182526920855428  14103100  1005           0  1fbe01fe    f3845767
# 2  10000554139829213984  14103100  1005           0  1fbe01fe    f3845767
# 3  10001094637809798845  14103100  1005           0  85f751fd    c4e18dd6
# 4  10001377041558670745  14103100  1005           0  85f751fd    c4e18dd6
# 5  10001521204153353724  14103100  1005           1  57fe1b20    5b626596
# 6  10001911056707023378  14103100  1005           0  1fbe01fe    f3845767
# 7  10001982898844213216  14103100  1005           0  85f751fd    c4e18dd6
# 8  10002000217531288531  14103100  1005           0  543a539e    c7ca3108
# 9  10002107385290585663  14103100  1005           0  1fbe01fe    f3845767
#
#   site_category    app_id app_domain app_category device_id device_ip  \
# 0      f028772b  ecad2386   7801e8d9     07d7df22  a99f214a  69f45779
# ...

# %%
train_df_sample.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
test_df_sample.columns
# Out:
# Index(['id', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %%
train_df_sample.dtypes
# Out:
# id                  float64
# click                 int64
# hour                  int64
# C1                    int64
# banner_pos            int64
# site_id              object
# site_domain          object
# site_category        object
# app_id               object
# app_domain           object
# app_category         object
# device_id            object
# device_ip            object
# device_model         object
# device_type           int64
# device_conn_type      int64
# C14                   int64
# C15                   int64
# C16                   int64
# C17                   int64
# C18                   int64
# C19                   int64
# C20                   int64
# C21                   int64
# dtype: object

# %%
# null值统计

# %%
train_null_index=train_df_sample.isna()
train_null_index.sum(axis=0)
# Out:
# id                  0
# click               0
# hour                0
# C1                  0
# banner_pos          0
# site_id             0
# site_domain         0
# site_category       0
# app_id              0
# app_domain          0
# app_category        0
# device_id           0
# device_ip           0
# device_model        0
# device_type         0
# device_conn_type    0
# C14                 0
# C15                 0
# C16                 0
# C17                 0
# C18                 0
# C19                 0
# C20                 0
# C21                 0
# dtype: int64

# %%
test_null_index=train_df_sample.isna()
test_null_index.sum(axis=0)
# Out:
# id                  0
# click               0
# hour                0
# C1                  0
# banner_pos          0
# site_id             0
# site_domain         0
# site_category       0
# app_id              0
# app_domain          0
# app_category        0
# device_id           0
# device_ip           0
# device_model        0
# device_type         0
# device_conn_type    0
# C14                 0
# C15                 0
# C16                 0
# C17                 0
# C18                 0
# C19                 0
# C20                 0
# C21                 0
# dtype: int64

# %%
# 样本均衡性检测
click_col=pd.read_csv(train_dir,usecols =["click"])

# %%
click_col.isna().sum(axis=0)
# Out:
# click    0
# dtype: int64

# %%
click_col["click"].value_counts()/click_col["click"].value_counts().sum()
# Out:
# 0   0.83019
# 1   0.16981
# Name: click, dtype: float64

# %%
test_df_sample.columns.shape
# Out:
# (23,)

# %%
# 总共只有23个特征 暂时不考虑降维处理

# %%
train_df_sample.shape
# Out:
# (100000, 24)

# %%
for col in train_df_sample.columns.values:
    print(train_df_sample[col].value_counts().sort_values(ascending=False).iloc[:2])
    print(train_df_sample[col].unique().shape)
    print("=================================")
# Out:
# 15405334732093083648.00000    1
# 10228061197030678528.00000    1
# Name: id, dtype: int64
# (100000,)
# ...
# 0    82510
# 1    17490
# Name: click, dtype: int64
# (2,)
# ...
# 14102100    100000
# Name: hour, dtype: int64
# (1,)
# ...
# 1005    92454
# 1002     4212
# Name: C1, dtype: int64
# (6,)
# ...
# 0    80249
# 1    19714
# Name: banner_pos, dtype: int64
# (5,)
# ...
# 1fbe01fe    35051
# 85f751fd    21773
# Name: site_id, dtype: int64
# (893,)
# ...
# f3845767    35051
# c4e18dd6    23398
# Name: site_domain, dtype: int64
# (780,)
# ...
# 28905ebd    37696
# 50e219e0    25399
# Name: site_category, dtype: int64
# (16,)
# ...
# ecad2386    78227
# febd1138     2367
# Name: app_id, dtype: int64
# (704,)
# ...
# 7801e8d9    82886
# 2347f47a     7509
# Name: app_domain, dtype: int64
# (55,)
# ...
# 07d7df22    78828
# 0f2161f8    14971
# Name: app_category, dtype: int64
# (19,)
# ...
# a99f214a    86935
# c357dbff      167
# Name: device_id, dtype: int64
# (7202,)
# ...
# 6b9769f2    838
# 9b1fe278    376
# Name: device_ip, dtype: int64
# (40376,)
# ...

# %%
click_col.shape
# Out:
# (40428967, 1)
